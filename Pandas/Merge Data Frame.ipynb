# %% [markdown]
# ## Pandas Merge Data Frame

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Merge two data frame by key/key

# %%
left = pd.DataFrame({
    'Key': ['K0', 'K1', 'K2', 'K3'],
    'K1' : ['K0', 'K1', 'K2', 'K3'],
    'K2' : ['K0', 'K1', 'K2', 'K3'],
    'A'  : ['A1', 'A2', 'A3', 'A3'],
    'B'  : ['B1', 'B2', 'B3', 'B4']
}, index=["R1", "R2", "R3", "R4"])
left
# Out:
#      A   B  K1  K2 Key
# R1  A1  B1  K0  K0  K0
# R2  A2  B2  K1  K1  K1
# R3  A3  B3  K2  K2  K2
# R4  A3  B4  K3  K3  K3

# %%
right = pd.DataFrame({
    'Key': ['K0', 'K1', 'K2', 'K3'],
    'K1' : ['K2', 'K2', 'K2', 'K3'],
    'K2' : ['K0', 'K1', 'K2', 'K3'],
    'C'  : ['C1', 'C2', 'C3', 'C3'],
    'D'  : ['D1', 'D2', 'D3', 'D4']
}, index=["R1", "R2", "R3", "R4"])
right
# Out:
#      C   D  K1  K2 Key
# R1  C1  D1  K2  K0  K0
# R2  C2  D2  K2  K1  K1
# R3  C3  D3  K2  K2  K2
# R4  C3  D4  K3  K3  K3

# %% [markdown]
# ### Merge Data Frame by Key

# %%
pd.merge(left, right, on="Key")
# Out:
#     A   B K1_x K2_x Key   C   D K1_y K2_y
# 0  A1  B1   K0   K0  K0  C1  D1   K2   K0
# 1  A2  B2   K1   K1  K1  C2  D2   K2   K1
# 2  A3  B3   K2   K2  K2  C3  D3   K2   K2
# 3  A3  B4   K3   K3  K3  C3  D4   K3   K3

# %%
pd.merge(left, right, on=["Key", "K1","K2"])
# Out:
#     A   B  K1  K2 Key   C   D
# 0  A3  B3  K2  K2  K2  C3  D3
# 1  A3  B4  K3  K3  K3  C3  D4

# %% [markdown]
# ### By default, it's inner join merge, to apply outer join
# - how = "outer"

# %%
pd.merge(left, right, on=["Key", "K1","K2"], how='outer')
# Out:
#      A    B  K1  K2 Key    C    D
# 0   A1   B1  K0  K0  K0  NaN  NaN
# 1   A2   B2  K1  K1  K1  NaN  NaN
# 2   A3   B3  K2  K2  K2   C3   D3
# 3   A3   B4  K3  K3  K3   C3   D4
# 4  NaN  NaN  K2  K0  K0   C1   D1
# 5  NaN  NaN  K2  K1  K1   C2   D2

# %% [markdown]
# ### Use indicator to know how it is merged

# %%
pd.merge(left, right, on=["Key", "K1","K2"], how='outer', indicator=True)
# Out:
#      A    B  K1  K2 Key    C    D      _merge
# 0   A1   B1  K0  K0  K0  NaN  NaN   left_only
# 1   A2   B2  K1  K1  K1  NaN  NaN   left_only
# 2   A3   B3  K2  K2  K2   C3   D3        both
# 3   A3   B4  K3  K3  K3   C3   D4        both
# 4  NaN  NaN  K2  K0  K0   C1   D1  right_only
# 5  NaN  NaN  K2  K1  K1   C2   D2  right_only

# %% [markdown]
# ### We can also give a name for indicator column instead of using default '_merge' column

# %%
pd.merge(left, right, on=["Key", "K1","K2"], how='outer', indicator='indicator_column')
# Out:
#      A    B  K1  K2 Key    C    D indicator_column
# 0   A1   B1  K0  K0  K0  NaN  NaN        left_only
# 1   A2   B2  K1  K1  K1  NaN  NaN        left_only
# 2   A3   B3  K2  K2  K2   C3   D3             both
# 3   A3   B4  K3  K3  K3   C3   D4             both
# 4  NaN  NaN  K2  K0  K0   C1   D1       right_only
# 5  NaN  NaN  K2  K1  K1   C2   D2       right_only

# %% [markdown]
# # Merge Data Frame by Row Index

# %%
pd.merge(left, right, left_index=True, right_index=True, how="outer")
# Out:
#      A   B K1_x K2_x Key_x   C   D K1_y K2_y Key_y
# R1  A1  B1   K0   K0    K0  C1  D1   K2   K0    K0
# R2  A2  B2   K1   K1    K1  C2  D2   K2   K1    K1
# R3  A3  B3   K2   K2    K2  C3  D3   K2   K2    K2
# R4  A3  B4   K3   K3    K3  C3  D4   K3   K3    K3

# %%
pd.merge(left, right, left_index=True, right_index=True, how="inner")
# Out:
#      A   B K1_x K2_x Key_x   C   D K1_y K2_y Key_y
# R1  A1  B1   K0   K0    K0  C1  D1   K2   K0    K0
# R2  A2  B2   K1   K1    K1  C2  D2   K2   K1    K1
# R3  A3  B3   K2   K2    K2  C3  D3   K2   K2    K2
# R4  A3  B4   K3   K3    K3  C3  D4   K3   K3    K3

# %% [markdown]
# # Merge Data Frame but Distinguish Column Names

# %%
boys = pd.DataFrame({
    "k": ["A", "B", "C"],
    "age": [1,2,3]
})
boys
# Out:
#    age  k
# 0    1  A
# 1    2  B
# 2    3  C

# %%
girls = pd.DataFrame({
    "k": ["A", "B", "C"],
    "age": [4,5,6]
})
girls
# Out:
#    age  k
# 0    4  A
# 1    5  B
# 2    6  C

# %% [markdown]
# ### Add suffix for same col names

# %%
pd.merge(boys, girls, on="k", suffixes=["_boys", "_girls"])
# Out:
#    age_boys  k  age_girls
# 0         1  A          4
# 1         2  B          5
# 2         3  C          6
