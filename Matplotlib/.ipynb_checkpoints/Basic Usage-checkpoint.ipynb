# %% [markdown]
# ## Matplotlib Basic Usage

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Make some data

# %%
x = np.linspace(-1, 1, 50)
y = 2 * x + 1

# %% [markdown]
# ### Show the plot

# %%
plt.plot(x, y)
plt.show()
