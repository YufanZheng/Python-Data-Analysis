# %% [markdown]
# # Simple path

# %%
import networkx as nx

# %%
G = nx.karate_club_graph()

# %%
sorted(nx.all_simple_paths(G, 1, 12))
# Out:
# [[1, 0, 2, 3, 12],
#  [1, 0, 2, 7, 3, 12],
#  [1, 0, 2, 8, 30, 32, 14, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 15, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 18, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 20, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 22, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 24, 27, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 24, 31, 28, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 24, 31, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 31, 24, 27, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 31, 28, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 25, 31, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 27, 24, 25, 31, 28, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 27, 24, 25, 31, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 27, 24, 31, 28, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 27, 24, 31, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 27, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 29, 26, 33, 13, 3, 12],
#  [1, 0, 2, 8, 30, 32, 23, 29, 33, 13, 3, 12],
# ...
